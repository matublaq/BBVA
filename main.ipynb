# %% [markdown]
# <p style="text-align: center; font-size: 45px; color: Skyblue;">SQL</p>

# %%
import sqlite3
import psycopg2
from DataBase_functions import *

# %%
def create_database():
    # Connect/Create a database
    conn = sqlite3.connnect("BBVA.db")
    cursor = conn.cursor()

    #Create a UUAA table
    cursor.execute('''
        CREATE TABLE IF NOT EXISTS UUAA (
            UUAA VARCHAR(4) PRIMARY KEY,
            description VARCHAR(50) NOT NULL
        )
    ''')

    #Create a Geofraphy table
    cursor.execute('''
        CREATE TABLE IF NOT EXISTS Geography (
            Geography_id INTEGER PRIMARY KEY,
            geography VARCHAR(50) NOT NULL
        )
    ''')

    # Create a versions table
    cursor.execute('''
        CREATE TABLE IF NOT EXISTS Versions (
            version_id INTEGER PRIMARY KEY,
            version integer NOT NULL, 
            description varchar(50) NOT NULL, 
            date date NOT NULL
        )
    ''')

    #Create a Versions_v2 table
    cursor.execute('''
        CREATE TABLE IF NOT EXISTS Versions_v2 (
            UUAA VARCHAR(4) NOT NULL,
            Gegrpahy_id INTEGER NOT NULL,
            version INTEGER NOT NULL,
            date date NOT NULL,
            description varchar(50) NOT NULL,
            PRIMARY KEY (UUAA, Geography_id),
            FOREIGN KEY (UUAA) REFERENCES UUAA(UUAA),
            FOREIGN KEY (Geography_id) REFERENCES Geography(Geography_id)
        )
    ''')

    # Create a petición table
    Cursor.execute('''
        CREATE TABLE IF NOT EXISTS Peticion (
            Peticion_code VARCHAR(12) PRIMARY KEY,
            DQDP_code VARCHAR(12) NOT NULL,
            sdatool VARCHAR(12) NOT NULL,
            feature VARCHAR(12) NOT NULL,
            UUAA VARCHAR(4) NOT NULL,
            Tiempo integer, 
            estado_id integer NOT NULL,
            fecha date NOT NULL,
            descripcion varchar(50) NOT NULL,
            FOREIGN KEY (UUAA) REFERENCES UUAA(UUAA),
            FOREIGN KEY (estado_id) REFERENCES Estados(estado_id)
        )
    ''')

    # Create a Peticion_version table
    Cursor.execute('''
        CREATE TABLE IF NOT EXISTS Peticion_version (
            Peticion_code VARCHAR(12) NOT NULL,
            version_id INTEGER NOT NULL,
            PRIMARY KEY (Peticion_code, version_id),
            FOREIGN KEY (Peticion_code) REFERENCES Peticion(Peticion_code),
            FOREIGN KEY (version_id) REFERENCES Versions(version_id)
        )
    ''')

    # Create a Estados table
    Cursor.execute('''
        CREATE TABLE IF NOT EXISTS Estados (
            Estado_id INTEGER PRIMARY KEY,
            estado enum('Abierto', 'Cerrado', 'En proceso') NOT NULL
        )
    ''')
